# %% [markdown]
# # 01 — Análise Exploratória (EDA)
#
# Exploração do dataset BRFSS 2015 de risco de diabetes: prevalência do alvo,
# distribuições das features, correlações e recorte por subgrupos sensíveis.
#
# > A lógica de produção fica em `src/`; o notebook é só para exploração.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from data.loader import load_raw
from features.engineering import engineer_features
from visualization.theme import apply_theme

RANDOM_SEED = 42
rng = np.random.default_rng(RANDOM_SEED)
rng.normal()
apply_theme()

# %%
df = engineer_features(load_raw())
print(df.shape)
df.head()

# %% [markdown]
# ## Prevalência da variável-alvo e distribuição por subgrupos
#
# ⟨Explorar `Diabetes_binary` por `Sex`, `AgeBand`, `Income` e `Education`.⟩
